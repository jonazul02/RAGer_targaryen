# %%
import pandas as pd

# %%
df = pd.read_csv("D:\\Proyectos\\Docker\\Multimodal_RAG\\Github\\RARger_targaryen\\assets\\recepies\\Food Ingredients and Recipe Dataset with Image Name Mapping.csv")

# %%
df_1 = df.sample(10).copy()

# %%
df_1.to_csv("D:\\Proyectos\\Docker\\Multimodal_RAG\\Github\\RARger_targaryen\\assets\\recepies\\Food Ingredients and Recipe Dataset with Image Name Mapping sample.csv",index=False)

# %%
import os 

path = 'D:\\Proyectos\\Docker\\Multimodal_RAG\\Github\\RARger_targaryen\\assets\\recepies\\Food_Images\\'

images_2_keep = [path + img+'.jpg' for img in df_1.Image_Name.tolist()]

images_2_erase = [path + img+'.jpg' for img in df.Image_Name.tolist() if path + img+'.jpg' not in  images_2_keep]

# %%
images_2_keep
# Out:
# ['D:\\Proyectos\\Docker\\Multimodal_RAG\\Github\\RARger_targaryen\\assets\\recepies\\Food_Images\\grilled-whole-eggplant-with-harissa-vinaigrette.jpg',
#  'D:\\Proyectos\\Docker\\Multimodal_RAG\\Github\\RARger_targaryen\\assets\\recepies\\Food_Images\\oysters-rockefeller-231165.jpg',
#  'D:\\Proyectos\\Docker\\Multimodal_RAG\\Github\\RARger_targaryen\\assets\\recepies\\Food_Images\\fiorentini-with-butternut-squash-51143810.jpg',
#  'D:\\Proyectos\\Docker\\Multimodal_RAG\\Github\\RARger_targaryen\\assets\\recepies\\Food_Images\\pink-peppercorn-bacon-51205330.jpg',
#  'D:\\Proyectos\\Docker\\Multimodal_RAG\\Github\\RARger_targaryen\\assets\\recepies\\Food_Images\\wasabi-and-green-onion-mashed-potatoes-240409.jpg',
#  'D:\\Proyectos\\Docker\\Multimodal_RAG\\Github\\RARger_targaryen\\assets\\recepies\\Food_Images\\mole-roasted-turkey-with-masa-stuffing-and-chile-gravy-240455.jpg',
# ...

# %%
import os
from pathlib import Path

for img in images_2_erase:
    img_path = Path(img)
    if img_path.exists():
        print(f"🗑️ Borrando: {img_path}")
        os.remove(img_path)
    else:
        print(f"❌ No encontrado: {img_path}")
        
cleaned_images = [Path(p.strip().strip('"').strip("'").replace('\\\\', '/').replace('\\', '/')).resolve() for p in images_2_erase]
# Out:
# ❌ No encontrado: D:\Proyectos\Docker\Multimodal_RAG\Github\RARger_targaryen\assets\recepies\Food_Images\miso-butter-roast-chicken-acorn-squash-panzanella.jpg
# ❌ No encontrado: D:\Proyectos\Docker\Multimodal_RAG\Github\RARger_targaryen\assets\recepies\Food_Images\crispy-salt-and-pepper-potatoes-dan-kluger.jpg
# ❌ No encontrado: D:\Proyectos\Docker\Multimodal_RAG\Github\RARger_targaryen\assets\recepies\Food_Images\thanksgiving-mac-and-cheese-erick-williams.jpg
# ❌ No encontrado: D:\Proyectos\Docker\Multimodal_RAG\Github\RARger_targaryen\assets\recepies\Food_Images\italian-sausage-and-bread-stuffing-240559.jpg
# ❌ No encontrado: D:\Proyectos\Docker\Multimodal_RAG\Github\RARger_targaryen\assets\recepies\Food_Images\newtons-law-apple-bourbon-cocktail.jpg
# ❌ No encontrado: D:\Proyectos\Docker\Multimodal_RAG\Github\RARger_targaryen\assets\recepies\Food_Images\warm-comfort-tequila-chamomile-toddy.jpg
# ...

# %%
import os
from pathlib import Path

# 1️⃣ Define la lista de imágenes que quieres conservar (lista blanca)
allowed_images = [
    'D:\\Proyectos\\Docker\\Multimodal_RAG\\Github\\RARger_targaryen\\assets\\recepies\\Food_Images\\grilled-whole-eggplant-with-harissa-vinaigrette.jpg',
    'D:\\Proyectos\\Docker\\Multimodal_RAG\\Github\\RARger_targaryen\\assets\\recepies\\Food_Images\\oysters-rockefeller-231165.jpg',
    'D:\\Proyectos\\Docker\\Multimodal_RAG\\Github\\RARger_targaryen\\assets\\recepies\\Food_Images\\fiorentini-with-butternut-squash-51143810.jpg',
    'D:\\Proyectos\\Docker\\Multimodal_RAG\\Github\\RARger_targaryen\\assets\\recepies\\Food_Images\\pink-peppercorn-bacon-51205330.jpg',
    'D:\\Proyectos\\Docker\\Multimodal_RAG\\Github\\RARger_targaryen\\assets\\recepies\\Food_Images\\wasabi-and-green-onion-mashed-potatoes-240409.jpg',
    'D:\\Proyectos\\Docker\\Multimodal_RAG\\Github\\RARger_targaryen\\assets\\recepies\\Food_Images\\mole-roasted-turkey-with-masa-stuffing-and-chile-gravy-240455.jpg',
    'D:\\Proyectos\\Docker\\Multimodal_RAG\\Github\\RARger_targaryen\\assets\\recepies\\Food_Images\\angel-hair-pasta-with-fennel-pesto.jpg',
    'D:\\Proyectos\\Docker\\Multimodal_RAG\\Github\\RARger_targaryen\\assets\\recepies\\Food_Images\\grilled-pork-shoulder-with-hoisin-and-molasses.jpg',
    'D:\\Proyectos\\Docker\\Multimodal_RAG\\Github\\RARger_targaryen\\assets\\recepies\\Food_Images\\win-son-bakerys-red-date-cake-jujubes.jpg',
    'D:\\Proyectos\\Docker\\Multimodal_RAG\\Github\\RARger_targaryen\\assets\\recepies\\Food_Images\\roasted-pear-crumble-51193110.jpg',
]

# 2️⃣ Convertimos a objetos Path normalizados
allowed_paths = [Path(p).resolve() for p in allowed_images]

# 3️⃣ Carpeta donde están las imágenes
images_folder = Path("D:/Proyectos/Docker/Multimodal_RAG/Github/RARger_targaryen/assets/recepies/Food_Images").resolve()

# 4️⃣ Borramos todo lo que NO esté en la lista
deleted_count = 0

for image_file in images_folder.glob("*.jpg"):
    if image_file not in allowed_paths:
        print(f"🗑️ Eliminando: {image_file}")
        image_file.unlink()
        deleted_count += 1
    else:
        print(f"✅ Conservando: {image_file.name}")

print(f"\n🚮 Total eliminadas: {deleted_count}")
# Out:
# ✅ Conservando: angel-hair-pasta-with-fennel-pesto.jpg
# 🗑️ Eliminando: D:\Proyectos\Docker\Multimodal_RAG\Github\RARger_targaryen\assets\recepies\Food_Images\angled-loofah-bread-and-butter-pickles-107780.jpg
# 🗑️ Eliminando: D:\Proyectos\Docker\Multimodal_RAG\Github\RARger_targaryen\assets\recepies\Food_Images\arugula-and-pear-salad-with-mascarpone-and-toasted-walnuts-107798.jpg
# 🗑️ Eliminando: D:\Proyectos\Docker\Multimodal_RAG\Github\RARger_targaryen\assets\recepies\Food_Images\baked-pears-with-sauternes-custard-sauce-105517.jpg
# 🗑️ Eliminando: D:\Proyectos\Docker\Multimodal_RAG\Github\RARger_targaryen\assets\recepies\Food_Images\baked-shrimp-toasts-108879.jpg
# 🗑️ Eliminando: D:\Proyectos\Docker\Multimodal_RAG\Github\RARger_targaryen\assets\recepies\Food_Images\basic-method-for-cooking-corn-on-the-cob-40047.jpg
# 🗑️ Eliminando: D:\Proyectos\Docker\Multimodal_RAG\Github\RARger_targaryen\assets\recepies\Food_Images\basic-muffins-40037.jpg
# ...
